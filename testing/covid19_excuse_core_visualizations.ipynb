# %%
import os, sys, numpy, pylab,importlib, pickle, gzip, json
from covid19_stats.engine import core, gis, viz
from covid19_stats import COVID19Database
from matplotlib.patches import Polygon
from itertools import chain
from nprstuff.core import autocrop_image
# %matplotlib inline

# %% [markdown]
# The `COVID19Database` singleton object, and the location of the `core` subdirectory for SPHINX docstring documentation.

# %%
cdat = COVID19Database( )
static_core_dir = '../docsrc/source/_static/core'
assert( os.path.isdir( static_core_dir ))

# %% [markdown]
# Gets geographical data from the `providence` MSA

# %%
core.get_msa_data( 'providence' )
# Out:
# {'prefix': 'providence',
#  'region name': 'Providence Metro Area',
#  'fips': {'25005', '44001', '44003', '44005', '44007', '44009'},
#  'population': 1624578}

# %%
core.get_data_fips('00001')
# Out:
# [{'date': datetime.date(2020, 3, 1),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 1,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 2),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 1,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 3),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 2,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 4),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 2,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 5),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 4,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 6),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 5,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 7),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 12,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 8),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 14,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 9),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 20,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 10),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 37,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 11),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 52,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 12),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 96,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 13),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 155,
#   'cumulative death': 0},
#  {'date': datetime.date(2020, 3, 14),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 269,
#   'cumulative death': 1},
#  {'date': datetime.date(2020, 3, 15),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 330,
#   'cumulative death': 5},
#  {'date': datetime.date(2020, 3, 16),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 464,
#   'cumulative death': 7},
#  {'date': datetime.date(2020, 3, 17),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 646,
#   'cumulative death': 11},
#  {'date': datetime.date(2020, 3, 18),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 1344,
#   'cumulative death': 25},
#  {'date': datetime.date(2020, 3, 19),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 2477,
#   'cumulative death': 31},
#  {'date': datetime.date(2020, 3, 20),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 4419,
#   'cumulative death': 54},
#  {'date': datetime.date(2020, 3, 21),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 6226,
#   'cumulative death': 75},
#  {'date': datetime.date(2020, 3, 22),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 9065,
#   'cumulative death': 119},
#  {'date': datetime.date(2020, 3, 23),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 12329,
#   'cumulative death': 155},
#  {'date': datetime.date(2020, 3, 24),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 14943,
#   'cumulative death': 230},
#  {'date': datetime.date(2020, 3, 25),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 20061,
#   'cumulative death': 330},
#  {'date': datetime.date(2020, 3, 26),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 23182,
#   'cumulative death': 435},
#  {'date': datetime.date(2020, 3, 27),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 25509,
#   'cumulative death': 560},
#  {'date': datetime.date(2020, 3, 28),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 30919,
#   'cumulative death': 825},
#  {'date': datetime.date(2020, 3, 29),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 33983,
#   'cumulative death': 991},
#  {'date': datetime.date(2020, 3, 30),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 38375,
#   'cumulative death': 1202},
#  {'date': datetime.date(2020, 3, 31),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 43518,
#   'cumulative death': 1475},
#  {'date': datetime.date(2020, 4, 1),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 47914,
#   'cumulative death': 1848},
#  {'date': datetime.date(2020, 4, 2),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 52400,
#   'cumulative death': 2152},
#  {'date': datetime.date(2020, 4, 3),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 57941,
#   'cumulative death': 2648},
#  {'date': datetime.date(2020, 4, 4),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 64274,
#   'cumulative death': 3221},
#  {'date': datetime.date(2020, 4, 5),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 68726,
#   'cumulative death': 3646},
#  {'date': datetime.date(2020, 4, 6),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 73553,
#   'cumulative death': 4857},
#  {'date': datetime.date(2020, 4, 7),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 78498,
#   'cumulative death': 5631},
#  {'date': datetime.date(2020, 4, 8),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 83673,
#   'cumulative death': 6441},
#  {'date': datetime.date(2020, 4, 9),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 89127,
#   'cumulative death': 7249},
#  {'date': datetime.date(2020, 4, 10),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 94702,
#   'cumulative death': 7981},
#  {'date': datetime.date(2020, 4, 11),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 100840,
#   'cumulative death': 8734},
#  {'date': datetime.date(2020, 4, 12),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 105939,
#   'cumulative death': 9448},
#  {'date': datetime.date(2020, 4, 13),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 109706,
#   'cumulative death': 10096},
#  {'date': datetime.date(2020, 4, 14),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 113632,
#   'cumulative death': 10857},
#  {'date': datetime.date(2020, 4, 15),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 121653,
#   'cumulative death': 11566},
#  {'date': datetime.date(2020, 4, 16),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 126623,
#   'cumulative death': 12109},
#  {'date': datetime.date(2020, 4, 17),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 131003,
#   'cumulative death': 12283},
#  {'date': datetime.date(2020, 4, 18),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 135052,
#   'cumulative death': 12411},
#  {'date': datetime.date(2020, 4, 19),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 138370,
#   'cumulative death': 13632},
#  {'date': datetime.date(2020, 4, 20),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 140881,
#   'cumulative death': 14074},
#  {'date': datetime.date(2020, 4, 21),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 143547,
#   'cumulative death': 14513},
#  {'date': datetime.date(2020, 4, 22),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 146787,
#   'cumulative death': 14959},
#  {'date': datetime.date(2020, 4, 23),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 150327,
#   'cumulative death': 15361},
#  {'date': datetime.date(2020, 4, 24),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 155081,
#   'cumulative death': 15754},
#  {'date': datetime.date(2020, 4, 25),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 159851,
#   'cumulative death': 16146},
#  {'date': datetime.date(2020, 4, 26),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 163106,
#   'cumulative death': 16486},
#  {'date': datetime.date(2020, 4, 27),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 165463,
#   'cumulative death': 16821},
#  {'date': datetime.date(2020, 4, 28),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 167487,
#   'cumulative death': 17206},
#  {'date': datetime.date(2020, 4, 29),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 170124,
#   'cumulative death': 17597},
#  {'date': datetime.date(2020, 4, 30),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 172784,
#   'cumulative death': 17809},
#  {'date': datetime.date(2020, 5, 1),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 174931,
#   'cumulative death': 17931},
#  {'date': datetime.date(2020, 5, 2),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 177490,
#   'cumulative death': 18021},
#  {'date': datetime.date(2020, 5, 3),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 179728,
#   'cumulative death': 18451},
#  {'date': datetime.date(2020, 5, 4),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 181034,
#   'cumulative death': 18580},
#  {'date': datetime.date(2020, 5, 5),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 182318,
#   'cumulative death': 18719},
#  {'date': datetime.date(2020, 5, 6),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 183770,
#   'cumulative death': 18993},
#  {'date': datetime.date(2020, 5, 7),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 185653,
#   'cumulative death': 19141},
#  {'date': datetime.date(2020, 5, 8),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 187157,
#   'cumulative death': 19210},
#  {'date': datetime.date(2020, 5, 9),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 188663,
#   'cumulative death': 19324},
#  {'date': datetime.date(2020, 5, 10),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 189656,
#   'cumulative death': 19436},
#  {'date': datetime.date(2020, 5, 11),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 190546,
#   'cumulative death': 19563},
#  {'date': datetime.date(2020, 5, 12),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 191320,
#   'cumulative death': 19736},
#  {'date': datetime.date(2020, 5, 13),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 192394,
#   'cumulative death': 19815},
#  {'date': datetime.date(2020, 5, 14),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 193663,
#   'cumulative death': 19904},
#  {'date': datetime.date(2020, 5, 15),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 195472,
#   'cumulative death': 19972},
#  {'date': datetime.date(2020, 5, 16),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 196481,
#   'cumulative death': 20071},
#  {'date': datetime.date(2020, 5, 17),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 197486,
#   'cumulative death': 20214},
#  {'date': datetime.date(2020, 5, 18),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 198114,
#   'cumulative death': 20298},
#  {'date': datetime.date(2020, 5, 19),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 198710,
#   'cumulative death': 20376},
#  {'date': datetime.date(2020, 5, 20),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 199392,
#   'cumulative death': 20422},
#  {'date': datetime.date(2020, 5, 21),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 200507,
#   'cumulative death': 20491},
#  {'date': datetime.date(2020, 5, 22),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 201298,
#   'cumulative death': 20569},
#  {'date': datetime.date(2020, 5, 23),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 202062,
#   'cumulative death': 20621},
#  {'date': datetime.date(2020, 5, 24),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 202931,
#   'cumulative death': 20697},
#  {'date': datetime.date(2020, 5, 25),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 203569,
#   'cumulative death': 20740},
#  {'date': datetime.date(2020, 5, 26),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 204111,
#   'cumulative death': 20795},
#  {'date': datetime.date(2020, 5, 27),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 204781,
#   'cumulative death': 20844},
#  {'date': datetime.date(2020, 5, 28),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 205854,
#   'cumulative death': 20895},
#  {'date': datetime.date(2020, 5, 29),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 206800,
#   'cumulative death': 20960},
#  {'date': datetime.date(2020, 5, 30),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 207539,
#   'cumulative death': 20991},
#  {'date': datetime.date(2020, 5, 31),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 208085,
#   'cumulative death': 21050},
#  {'date': datetime.date(2020, 6, 1),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 208550,
#   'cumulative death': 21090},
#  {'date': datetime.date(2020, 6, 2),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 209195,
#   'cumulative death': 21132},
#  {'date': datetime.date(2020, 6, 3),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 209688,
#   'cumulative death': 21170},
#  {'date': datetime.date(2020, 6, 4),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 210227,
#   'cumulative death': 21234},
#  {'date': datetime.date(2020, 6, 5),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 210728,
#   'cumulative death': 21262},
#  {'date': datetime.date(2020, 6, 6),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 211274,
#   'cumulative death': 21294},
#  {'date': datetime.date(2020, 6, 7),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 211728,
#   'cumulative death': 21323},
#  {'date': datetime.date(2020, 6, 8),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 212122,
#   'cumulative death': 21356},
#  {'date': datetime.date(2020, 6, 9),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 212469,
#   'cumulative death': 21396},
#  {'date': datetime.date(2020, 6, 10),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 212884,
#   'cumulative death': 21436},
#  {'date': datetime.date(2020, 6, 11),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 213271,
#   'cumulative death': 21468},
#  {'date': datetime.date(2020, 6, 12),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 213707,
#   'cumulative death': 21519},
#  {'date': datetime.date(2020, 6, 13),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 214242,
#   'cumulative death': 21551},
#  {'date': datetime.date(2020, 6, 14),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 214627,
#   'cumulative death': 21578},
#  {'date': datetime.date(2020, 6, 15),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 215011,
#   'cumulative death': 21600},
#  {'date': datetime.date(2020, 6, 16),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 215342,
#   'cumulative death': 21619},
#  {'date': datetime.date(2020, 6, 17),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 215686,
#   'cumulative death': 21645},
#  {'date': datetime.date(2020, 6, 18),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 216013,
#   'cumulative death': 21673},
#  {'date': datetime.date(2020, 6, 19),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 216421,
#   'cumulative death': 21710},
#  {'date': datetime.date(2020, 6, 20),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 216803,
#   'cumulative death': 21719},
#  {'date': datetime.date(2020, 6, 21),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 217189,
#   'cumulative death': 21753},
#  {'date': datetime.date(2020, 6, 22),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 217487,
#   'cumulative death': 21796},
#  {'date': datetime.date(2020, 6, 23),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 217803,
#   'cumulative death': 21817},
#  {'date': datetime.date(2020, 6, 24),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 218089,
#   'cumulative death': 21838},
#  {'date': datetime.date(2020, 6, 25),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 218429,
#   'cumulative death': 21856},
#  {'date': datetime.date(2020, 6, 26),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 218799,
#   'cumulative death': 21893},
#  {'date': datetime.date(2020, 6, 27),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 219157,
#   'cumulative death': 21913},
#  {'date': datetime.date(2020, 6, 28),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 219481,
#   'cumulative death': 21940},
#  {'date': datetime.date(2020, 6, 29),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 219670,
#   'cumulative death': 21941},
#  {'date': datetime.date(2020, 6, 30),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 219844,
#   'cumulative death': 22566},
#  {'date': datetime.date(2020, 7, 1),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 220143,
#   'cumulative death': 22574},
#  {'date': datetime.date(2020, 7, 2),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 220567,
#   'cumulative death': 22593},
#  {'date': datetime.date(2020, 7, 3),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 221028,
#   'cumulative death': 22610},
#  {'date': datetime.date(2020, 7, 4),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 221395,
#   'cumulative death': 22630},
#  {'date': datetime.date(2020, 7, 5),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 221637,
#   'cumulative death': 22661},
#  {'date': datetime.date(2020, 7, 6),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 221882,
#   'cumulative death': 22672},
#  {'date': datetime.date(2020, 7, 7),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 222156,
#   'cumulative death': 22690},
#  {'date': datetime.date(2020, 7, 8),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 222444,
#   'cumulative death': 22696},
#  {'date': datetime.date(2020, 7, 9),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 222723,
#   'cumulative death': 22719},
#  {'date': datetime.date(2020, 7, 10),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 223078,
#   'cumulative death': 22739},
#  {'date': datetime.date(2020, 7, 11),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 223382,
#   'cumulative death': 22750},
#  {'date': datetime.date(2020, 7, 12),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 223725,
#   'cumulative death': 22755},
#  {'date': datetime.date(2020, 7, 13),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 223977,
#   'cumulative death': 22795},
#  {'date': datetime.date(2020, 7, 14),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 224293,
#   'cumulative death': 22808},
#  {'date': datetime.date(2020, 7, 15),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 224662,
#   'cumulative death': 22825},
#  {'date': datetime.date(2020, 7, 16),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 225045,
#   'cumulative death': 22842},
#  {'date': datetime.date(2020, 7, 17),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 225414,
#   'cumulative death': 22848},
#  {'date': datetime.date(2020, 7, 18),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 225799,
#   'cumulative death': 22859},
#  {'date': datetime.date(2020, 7, 19),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 226104,
#   'cumulative death': 22872},
#  {'date': datetime.date(2020, 7, 20),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 226388,
#   'cumulative death': 22882},
#  {'date': datetime.date(2020, 7, 21),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 226779,
#   'cumulative death': 22895},
#  {'date': datetime.date(2020, 7, 22),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 227130,
#   'cumulative death': 22899},
#  {'date': datetime.date(2020, 7, 23),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 227517,
#   'cumulative death': 22934},
#  {'date': datetime.date(2020, 7, 24),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 227882,
#   'cumulative death': 22936},
#  {'date': datetime.date(2020, 7, 25),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 228220,
#   'cumulative death': 22947},
#  {'date': datetime.date(2020, 7, 26),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 228445,
#   'cumulative death': 22956},
#  {'date': datetime.date(2020, 7, 27),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 228740,
#   'cumulative death': 22970},
#  {'date': datetime.date(2020, 7, 28),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 228939,
#   'cumulative death': 22977},
#  {'date': datetime.date(2020, 7, 29),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 229237,
#   'cumulative death': 22982},
#  {'date': datetime.date(2020, 7, 30),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 229551,
#   'cumulative death': 22996},
#  {'date': datetime.date(2020, 7, 31),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 229834,
#   'cumulative death': 23002},
#  {'date': datetime.date(2020, 8, 1),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 230147,
#   'cumulative death': 23007},
#  {'date': datetime.date(2020, 8, 2),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 230410,
#   'cumulative death': 23012},
#  {'date': datetime.date(2020, 8, 3),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 230648,
#   'cumulative death': 23021},
#  {'date': datetime.date(2020, 8, 4),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 230964,
#   'cumulative death': 23027},
#  {'date': datetime.date(2020, 8, 5),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 231268,
#   'cumulative death': 23034},
#  {'date': datetime.date(2020, 8, 6),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 231600,
#   'cumulative death': 23563},
#  {'date': datetime.date(2020, 8, 7),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 231942,
#   'cumulative death': 23567},
#  {'date': datetime.date(2020, 8, 8),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 232271,
#   'cumulative death': 23575},
#  {'date': datetime.date(2020, 8, 9),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 232517,
#   'cumulative death': 23580},
#  {'date': datetime.date(2020, 8, 10),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 232756,
#   'cumulative death': 23586},
#  {'date': datetime.date(2020, 8, 11),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 233030,
#   'cumulative death': 23592},
#  {'date': datetime.date(2020, 8, 12),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 233422,
#   'cumulative death': 23602},
#  {'date': datetime.date(2020, 8, 13),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 233859,
#   'cumulative death': 23610},
#  {'date': datetime.date(2020, 8, 14),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 234223,
#   'cumulative death': 23615},
#  {'date': datetime.date(2020, 8, 15),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 234609,
#   'cumulative death': 23621},
#  {'date': datetime.date(2020, 8, 16),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 234918,
#   'cumulative death': 23628},
#  {'date': datetime.date(2020, 8, 17),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 235155,
#   'cumulative death': 23634},
#  {'date': datetime.date(2020, 8, 18),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 235446,
#   'cumulative death': 23642},
#  {'date': datetime.date(2020, 8, 19),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 235714,
#   'cumulative death': 23643},
#  {'date': datetime.date(2020, 8, 20),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 235985,
#   'cumulative death': 23639},
#  {'date': datetime.date(2020, 8, 21),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 236269,
#   'cumulative death': 23641},
#  {'date': datetime.date(2020, 8, 22),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 236534,
#   'cumulative death': 23646},
#  {'date': datetime.date(2020, 8, 23),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 236822,
#   'cumulative death': 23658},
#  {'date': datetime.date(2020, 8, 24),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 237032,
#   'cumulative death': 23662},
#  {'date': datetime.date(2020, 8, 25),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 237263,
#   'cumulative death': 23666},
#  {'date': datetime.date(2020, 8, 26),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 237525,
#   'cumulative death': 23669},
#  {'date': datetime.date(2020, 8, 27),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 237838,
#   'cumulative death': 23674},
#  {'date': datetime.date(2020, 8, 28),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 238107,
#   'cumulative death': 23680},
#  {'date': datetime.date(2020, 8, 29),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 238385,
#   'cumulative death': 23683},
#  {'date': datetime.date(2020, 8, 30),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 238677,
#   'cumulative death': 23689},
#  {'date': datetime.date(2020, 8, 31),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 238938,
#   'cumulative death': 23695},
#  {'date': datetime.date(2020, 9, 1),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 239246,
#   'cumulative death': 23703},
#  {'date': datetime.date(2020, 9, 2),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 239512,
#   'cumulative death': 23708},
#  {'date': datetime.date(2020, 9, 3),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 239815,
#   'cumulative death': 23710},
#  {'date': datetime.date(2020, 9, 4),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 240139,
#   'cumulative death': 23716},
#  {'date': datetime.date(2020, 9, 5),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 240416,
#   'cumulative death': 23721},
#  {'date': datetime.date(2020, 9, 6),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 240711,
#   'cumulative death': 23721},
#  {'date': datetime.date(2020, 9, 7),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 240919,
#   'cumulative death': 23736},
#  {'date': datetime.date(2020, 9, 8),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 241141,
#   'cumulative death': 23744},
#  {'date': datetime.date(2020, 9, 9),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 241351,
#   'cumulative death': 23741},
#  {'date': datetime.date(2020, 9, 10),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 241686,
#   'cumulative death': 23741},
#  {'date': datetime.date(2020, 9, 11),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 241936,
#   'cumulative death': 23739},
#  {'date': datetime.date(2020, 9, 12),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 242242,
#   'cumulative death': 23743},
#  {'date': datetime.date(2020, 9, 13),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 242486,
#   'cumulative death': 23743},
#  {'date': datetime.date(2020, 9, 14),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 242754,
#   'cumulative death': 23750},
#  {'date': datetime.date(2020, 9, 15),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 243061,
#   'cumulative death': 23758},
#  {'date': datetime.date(2020, 9, 16),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 243314,
#   'cumulative death': 23762},
#  {'date': datetime.date(2020, 9, 17),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 243644,
#   'cumulative death': 23767},
#  {'date': datetime.date(2020, 9, 18),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 243995,
#   'cumulative death': 23775},
#  {'date': datetime.date(2020, 9, 19),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 244484,
#   'cumulative death': 23771},
#  {'date': datetime.date(2020, 9, 20),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 244885,
#   'cumulative death': 23777},
#  {'date': datetime.date(2020, 9, 21),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 245147,
#   'cumulative death': 23782},
#  {'date': datetime.date(2020, 9, 22),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 245495,
#   'cumulative death': 23780},
#  {'date': datetime.date(2020, 9, 23),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 245776,
#   'cumulative death': 23780},
#  {'date': datetime.date(2020, 9, 24),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 246198,
#   'cumulative death': 23785},
#  {'date': datetime.date(2020, 9, 25),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 246570,
#   'cumulative death': 23792},
#  {'date': datetime.date(2020, 9, 26),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 247000,
#   'cumulative death': 23795},
#  {'date': datetime.date(2020, 9, 27),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 247384,
#   'cumulative death': 23801},
#  {'date': datetime.date(2020, 9, 28),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 247765,
#   'cumulative death': 23810},
#  {'date': datetime.date(2020, 9, 29),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 248287,
#   'cumulative death': 23814},
#  {'date': datetime.date(2020, 9, 30),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 248738,
#   'cumulative death': 23823},
#  {'date': datetime.date(2020, 10, 1),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 249272,
#   'cumulative death': 23829},
#  {'date': datetime.date(2020, 10, 2),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 249874,
#   'cumulative death': 23846},
#  {'date': datetime.date(2020, 10, 3),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 250583,
#   'cumulative death': 23844},
#  {'date': datetime.date(2020, 10, 4),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 251119,
#   'cumulative death': 23852},
#  {'date': datetime.date(2020, 10, 5),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 251591,
#   'cumulative death': 23861},
#  {'date': datetime.date(2020, 10, 6),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 252159,
#   'cumulative death': 23866},
#  {'date': datetime.date(2020, 10, 7),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 252703,
#   'cumulative death': 23873},
#  {'date': datetime.date(2020, 10, 8),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 253398,
#   'cumulative death': 23874},
#  {'date': datetime.date(2020, 10, 9),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 254023,
#   'cumulative death': 23879},
#  {'date': datetime.date(2020, 10, 10),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 254599,
#   'cumulative death': 23882},
#  {'date': datetime.date(2020, 10, 11),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 255068,
#   'cumulative death': 23883},
#  {'date': datetime.date(2020, 10, 12),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 255464,
#   'cumulative death': 23890},
#  {'date': datetime.date(2020, 10, 13),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 256007,
#   'cumulative death': 23895},
#  {'date': datetime.date(2020, 10, 14),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 256474,
#   'cumulative death': 23905},
#  {'date': datetime.date(2020, 10, 15),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 256986,
#   'cumulative death': 23915},
#  {'date': datetime.date(2020, 10, 16),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 257642,
#   'cumulative death': 23915},
#  {'date': datetime.date(2020, 10, 17),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 258452,
#   'cumulative death': 23925},
#  {'date': datetime.date(2020, 10, 18),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 259064,
#   'cumulative death': 23935},
#  {'date': datetime.date(2020, 10, 19),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 259484,
#   'cumulative death': 23944},
#  {'date': datetime.date(2020, 10, 20),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 259920,
#   'cumulative death': 23944},
#  {'date': datetime.date(2020, 10, 21),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 260762,
#   'cumulative death': 23949},
#  {'date': datetime.date(2020, 10, 22),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 261293,
#   'cumulative death': 23955},
#  {'date': datetime.date(2020, 10, 23),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 261863,
#   'cumulative death': 23963},
#  {'date': datetime.date(2020, 10, 24),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 262615,
#   'cumulative death': 23963},
#  {'date': datetime.date(2020, 10, 25),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 263269,
#   'cumulative death': 23967},
#  {'date': datetime.date(2020, 10, 26),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 263694,
#   'cumulative death': 23969},
#  {'date': datetime.date(2020, 10, 27),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 264428,
#   'cumulative death': 23978},
#  {'date': datetime.date(2020, 10, 28),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 265263,
#   'cumulative death': 23980},
#  {'date': datetime.date(2020, 10, 29),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 266321,
#   'cumulative death': 23989},
#  {'date': datetime.date(2020, 10, 30),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 267227,
#   'cumulative death': 23996},
#  {'date': datetime.date(2020, 10, 31),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 267929,
#   'cumulative death': 24001},
#  {'date': datetime.date(2020, 11, 1),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 268879,
#   'cumulative death': 24013},
#  {'date': datetime.date(2020, 11, 2),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 269519,
#   'cumulative death': 24017},
#  {'date': datetime.date(2020, 11, 3),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 270317,
#   'cumulative death': 24021},
#  {'date': datetime.date(2020, 11, 4),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 271112,
#   'cumulative death': 24034},
#  {'date': datetime.date(2020, 11, 5),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 272184,
#   'cumulative death': 24047},
#  {'date': datetime.date(2020, 11, 6),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 273386,
#   'cumulative death': 24054},
#  {'date': datetime.date(2020, 11, 7),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 274551,
#   'cumulative death': 24060},
#  {'date': datetime.date(2020, 11, 8),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 275944,
#   'cumulative death': 24074},
#  {'date': datetime.date(2020, 11, 9),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 277105,
#   'cumulative death': 24085},
#  {'date': datetime.date(2020, 11, 10),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 278312,
#   'cumulative death': 24087},
#  {'date': datetime.date(2020, 11, 11),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 280044,
#   'cumulative death': 24096},
#  {'date': datetime.date(2020, 11, 12),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 281707,
#   'cumulative death': 24099},
#  {'date': datetime.date(2020, 11, 13),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 283533,
#   'cumulative death': 24108},
#  {'date': datetime.date(2020, 11, 14),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 285333,
#   'cumulative death': 24118},
#  {'date': datetime.date(2020, 11, 15),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 286785,
#   'cumulative death': 24124},
#  {'date': datetime.date(2020, 11, 16),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 288078,
#   'cumulative death': 24136},
#  {'date': datetime.date(2020, 11, 17),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 290018,
#   'cumulative death': 24146},
#  {'date': datetime.date(2020, 11, 18),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 291753,
#   'cumulative death': 24149},
#  {'date': datetime.date(2020, 11, 19),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 293592,
#   'cumulative death': 24167},
#  {'date': datetime.date(2020, 11, 20),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 295622,
#   'cumulative death': 24188},
#  {'date': datetime.date(2020, 11, 21),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 297570,
#   'cumulative death': 24202},
#  {'date': datetime.date(2020, 11, 22),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 299495,
#   'cumulative death': 24206},
#  {'date': datetime.date(2020, 11, 23),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 301282,
#   'cumulative death': 24218},
#  {'date': datetime.date(2020, 11, 24),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 303007,
#   'cumulative death': 24220},
#  {'date': datetime.date(2020, 11, 25),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 304925,
#   'cumulative death': 24230},
#  {'date': datetime.date(2020, 11, 26),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 307261,
#   'cumulative death': 24241},
#  {'date': datetime.date(2020, 11, 27),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 309822,
#   'cumulative death': 24255},
#  {'date': datetime.date(2020, 11, 28),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 311920,
#   'cumulative death': 24260},
#  {'date': datetime.date(2020, 11, 29),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 314223,
#   'cumulative death': 24268},
#  {'date': datetime.date(2020, 11, 30),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 316724,
#   'cumulative death': 24274},
#  {'date': datetime.date(2020, 12, 1),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 319301,
#   'cumulative death': 24287},
#  {'date': datetime.date(2020, 12, 2),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 322501,
#   'cumulative death': 24297},
#  {'date': datetime.date(2020, 12, 3),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 325806,
#   'cumulative death': 24305},
#  {'date': datetime.date(2020, 12, 4),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 329406,
#   'cumulative death': 24323},
#  {'date': datetime.date(2020, 12, 5),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 332633,
#   'cumulative death': 24346},
#  {'date': datetime.date(2020, 12, 6),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 335768,
#   'cumulative death': 24365},
#  {'date': datetime.date(2020, 12, 7),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 339610,
#   'cumulative death': 24387},
#  {'date': datetime.date(2020, 12, 8),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 342755,
#   'cumulative death': 24416},
#  {'date': datetime.date(2020, 12, 9),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 346834,
#   'cumulative death': 24411},
#  {'date': datetime.date(2020, 12, 10),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 350283,
#   'cumulative death': 24421},
#  {'date': datetime.date(2020, 12, 11),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 353596,
#   'cumulative death': 24450},
#  {'date': datetime.date(2020, 12, 12),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 357489,
#   'cumulative death': 24467},
#  {'date': datetime.date(2020, 12, 13),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 360700,
#   'cumulative death': 24501},
#  {'date': datetime.date(2020, 12, 14),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 363669,
#   'cumulative death': 24526},
#  {'date': datetime.date(2020, 12, 15),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 367198,
#   'cumulative death': 24561},
#  {'date': datetime.date(2020, 12, 16),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 370109,
#   'cumulative death': 24578},
#  {'date': datetime.date(2020, 12, 17),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 373320,
#   'cumulative death': 24613},
#  {'date': datetime.date(2020, 12, 18),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 377728,
#   'cumulative death': 24652},
#  {'date': datetime.date(2020, 12, 19),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 381067,
#   'cumulative death': 24677},
#  {'date': datetime.date(2020, 12, 20),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 383808,
#   'cumulative death': 24697},
#  {'date': datetime.date(2020, 12, 21),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 387595,
#   'cumulative death': 24735},
#  {'date': datetime.date(2020, 12, 22),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 391634,
#   'cumulative death': 24768},
#  {'date': datetime.date(2020, 12, 23),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 395810,
#   'cumulative death': 24790},
#  {'date': datetime.date(2020, 12, 24),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 401251,
#   'cumulative death': 24842},
#  {'date': datetime.date(2020, 12, 25),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 405857,
#   'cumulative death': 24889},
#  {'date': datetime.date(2020, 12, 26),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 410048,
#   'cumulative death': 24931},
#  {'date': datetime.date(2020, 12, 27),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 413472,
#   'cumulative death': 24973},
#  {'date': datetime.date(2020, 12, 28),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 416922,
#   'cumulative death': 25008},
#  {'date': datetime.date(2020, 12, 29),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 422074,
#   'cumulative death': 25055},
#  {'date': datetime.date(2020, 12, 30),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 426279,
#   'cumulative death': 25099},
#  {'date': datetime.date(2020, 12, 31),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 430863,
#   'cumulative death': 25144},
#  {'date': datetime.date(2021, 1, 1),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 436692,
#   'cumulative death': 25186},
#  {'date': datetime.date(2021, 1, 2),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 442695,
#   'cumulative death': 25211},
#  {'date': datetime.date(2021, 1, 3),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 446899,
#   'cumulative death': 25244},
#  {'date': datetime.date(2021, 1, 4),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 450658,
#   'cumulative death': 25284},
#  {'date': datetime.date(2021, 1, 5),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 455997,
#   'cumulative death': 25309},
#  {'date': datetime.date(2021, 1, 6),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 460988,
#   'cumulative death': 25362},
#  {'date': datetime.date(2021, 1, 7),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 467327,
#   'cumulative death': 25416},
#  {'date': datetime.date(2021, 1, 8),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 474339,
#   'cumulative death': 25453},
#  {'date': datetime.date(2021, 1, 9),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 481279,
#   'cumulative death': 25505},
#  {'date': datetime.date(2021, 1, 10),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 487551,
#   'cumulative death': 25562},
#  {'date': datetime.date(2021, 1, 11),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 493306,
#   'cumulative death': 25635},
#  {'date': datetime.date(2021, 1, 12),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 498877,
#   'cumulative death': 25698},
#  {'date': datetime.date(2021, 1, 13),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 504826,
#   'cumulative death': 25741},
#  {'date': datetime.date(2021, 1, 14),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 510711,
#   'cumulative death': 25834},
#  {'date': datetime.date(2021, 1, 15),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 517963,
#   'cumulative death': 25909},
#  {'date': datetime.date(2021, 1, 16),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 524231,
#   'cumulative death': 25970},
#  {'date': datetime.date(2021, 1, 17),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 529834,
#   'cumulative death': 26036},
#  {'date': datetime.date(2021, 1, 18),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 536287,
#   'cumulative death': 26104},
#  {'date': datetime.date(2021, 1, 19),
#   'county': 'New York City',
#   'state': 'New York',
#   'fips': '00001',
#   'cumulative cases': 541846,
#   'cumulative death': 26161}]

# %% [markdown]
# Now get latest (26 FEBRUARY 2021) incident data for `bayeara` MSA

# %%
inc_data_bayarea = core.get_incident_data( )
pickle.dump( inc_data_bayarea, gzip.open( os.path.join( static_core_dir, 'core_incident_data_bayarea.pkl.gz'), 'wb' ) )

# %%
inc_data_bayarea.keys()
# Out:
# dict_keys(['df', 'bbox', 'boundaries', 'last day'])

# %%
inc_data_bayarea['last day']
# Out:
# 354

# %%
inc_data_bayarea['df'].keys()
# Out:
# Index(['date', 'cases', 'death', 'days_from_beginning', 'cases_06001',
#        'deaths_06001', 'cases_06013', 'deaths_06013', 'cases_06041',
#        'deaths_06041', 'cases_06055', 'deaths_06055', 'cases_06069',
#        'deaths_06069', 'cases_06075', 'deaths_06075', 'cases_06081',
#        'deaths_06081', 'cases_06085', 'deaths_06085'],
#       dtype='object')

# %%
inc_data_bayarea['df'].days_from_beginning
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 350    350
# 351    351
# 352    352
# 353    353
# 354    354
# Name: days_from_beginning, Length: 355, dtype: int64

# %%
core.get_max_cases_county( inc_data_bayarea)
# Out:
# {'fips': '06085',
#  'cases': 94366,
#  'county': 'Santa Clara County',
#  'state': 'California'}

# %%
core.get_maximum_cases( inc_data_bayarea )
# Out:
# ('06085', 94366)

# %% [markdown]
# Now spit out the `display_tabulated_metros` as a list, for storage into JSON format.

# %%
summary_data = core.display_tabulated_metros( form='json')

# %%
summary_data[:2]
# Out:
# [{'RANK': 1,
#   'PREFIX': 'nyc',
#   'NAME': 'NYC Metro Area',
#   'POPULATION': 19216182,
#   'FIRST INC.': '01 March 2020',
#   'NUM DAYS': 324,
#   'NUM CASES': 1390557,
#   'NUM DEATHS': 50378,
#   'MAX CASE COUNTY': 541846,
#   'MAX CASE COUNTY NAME': 'New York City, New York'},
#  {'RANK': 2,
#   'PREFIX': 'losangeles',
#   'NAME': 'LA Metro Area',
#   'POPULATION': 18711436,
#   'FIRST INC.': '25 January 2020',
#   'NUM DAYS': 360,
#   'NUM CASES': 1828244,
#   'NUM DEATHS': 21240,
#   'MAX CASE COUNTY': 1032277,
#   'MAX CASE COUNTY NAME': 'Los Angeles County, California'}]

# %%
json.dump( summary_data, open( os.path.join( static_core_dir, 'core_summary_data.json'), 'w' ), indent = 1 )
